# %%
import xml.etree.ElementTree as ET
from pathlib import Path
import json
from statistics import mean

# converts python data structures to XML
import xmltodict

# %%
root = ET.Element('main')
ET.tostring(root, 'unicode')
# Out:
# '<main />'

# %%
data = []
for f in Path().rglob('../source_data/*/*.json'):
    city = f.parts[-2]
    json_data = json.loads(f.read_text())
    city_tag = ''.join(w.capitalize() for w in city.split())
    data.append({'city': city_tag, 'data': json_data})
data
# Out:
# [{'city': 'Oviedo',
#   'data': {'lat': 43.3606,
#    'lon': -5.8446,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632550439,
#     'sunset': 1632593763,
#     'temp': 15.84,
#     'feels_like': 16.09,
#     'pressure': 1011,
#     'humidity': 100,
#     'dew_point': 15.84,
#     'uvi': 0,
#     'clouds': 46,
#     'visibility': 10000,
#     'wind_speed': 1.79,
#     'wind_deg': 196,
#     'wind_gust': 2.24,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 15.84,
#      'feels_like': 16.09,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 15.84,
#      'uvi': 0,
#      'clouds': 46,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 196,
#      'wind_gust': 2.24,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632531600,
#      'temp': 15.91,
#      'feels_like': 16.17,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 15.91,
#      'uvi': 0,
#      'clouds': 42,
#      'visibility': 10000,
#      'wind_speed': 2.05,
#      'wind_deg': 198,
#      'wind_gust': 2.65,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632535200,
#      'temp': 14.83,
#      'feels_like': 14.98,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.83,
#      'uvi': 0,
#      'clouds': 66,
#      'visibility': 10000,
#      'wind_speed': 1.75,
#      'wind_deg': 194,
#      'wind_gust': 2.76,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632538800,
#      'temp': 14.3,
#      'feels_like': 14.4,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.3,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 184,
#      'wind_gust': 2.24,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632542400,
#      'temp': 14.26,
#      'feels_like': 14.35,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.26,
#      'uvi': 0,
#      'clouds': 82,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 180,
#      'wind_gust': 2.24,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632546000,
#      'temp': 14.43,
#      'feels_like': 14.54,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.43,
#      'uvi': 0,
#      'clouds': 83,
#      'visibility': 10000,
#      'wind_speed': 2.1,
#      'wind_deg': 193,
#      'wind_gust': 2.38,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632549600,
#      'temp': 14.65,
#      'feels_like': 14.78,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.65,
#      'uvi': 0,
#      'clouds': 96,
#      'visibility': 10000,
#      'wind_speed': 2.36,
#      'wind_deg': 193,
#      'wind_gust': 3.03,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04n'}]},
#     {'dt': 1632553200,
#      'temp': 14.62,
#      'feels_like': 14.75,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 14.62,
#      'uvi': 0,
#      'clouds': 97,
#      'visibility': 10000,
#      'wind_speed': 2.27,
#      'wind_deg': 190,
#      'wind_gust': 3.38,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632556800,
#      'temp': 15.75,
#      'feels_like': 15.08,
#      'pressure': 1013,
#      'humidity': 65,
#      'dew_point': 9.19,
#      'uvi': 0.31,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 1.75,
#      'wind_deg': 188,
#      'wind_gust': 3.28,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632560400,
#      'temp': 19.91,
#      'feels_like': 20.57,
#      'pressure': 1011,
#      'humidity': 100,
#      'dew_point': 19.91,
#      'uvi': 0.83,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 163,
#      'wind_gust': 1.34,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632564000,
#      'temp': 20.71,
#      'feels_like': 21.45,
#      'pressure': 1012,
#      'humidity': 100,
#      'dew_point': 20.71,
#      'uvi': 1.35,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 0.17,
#      'wind_deg': 194,
#      'wind_gust': 2.38,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632567600,
#      'temp': 21.96,
#      'feels_like': 22.82,
#      'pressure': 1012,
#      'humidity': 100,
#      'dew_point': 21.96,
#      'uvi': 1.93,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 194,
#      'wind_gust': 1.34,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632571200,
#      'temp': 19.22,
#      'feels_like': 19.39,
#      'pressure': 1013,
#      'humidity': 84,
#      'dew_point': 16.45,
#      'uvi': 2.28,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 222,
#      'wind_gust': 1.34,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632574800,
#      'temp': 18.81,
#      'feels_like': 19.1,
#      'pressure': 1012,
#      'humidity': 90,
#      'dew_point': 17.14,
#      'uvi': 0.58,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 211,
#      'wind_gust': 1.34,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.16}},
#     {'dt': 1632578400,
#      'temp': 18.84,
#      'feels_like': 19.05,
#      'pressure': 1013,
#      'humidity': 87,
#      'dew_point': 16.63,
#      'uvi': 0.48,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 232,
#      'wind_gust': 2.68,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.28}},
#     {'dt': 1632582000,
#      'temp': 19.39,
#      'feels_like': 19.58,
#      'pressure': 1012,
#      'humidity': 84,
#      'dew_point': 16.62,
#      'uvi': 0.32,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 14,
#      'wind_gust': 2.24,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632585600,
#      'temp': 19.47,
#      'feels_like': 19.51,
#      'pressure': 1012,
#      'humidity': 78,
#      'dew_point': 15.54,
#      'uvi': 0.54,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 25,
#      'wind_gust': 2.68,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632589200,
#      'temp': 19.15,
#      'feels_like': 19.16,
#      'pressure': 1012,
#      'humidity': 78,
#      'dew_point': 15.23,
#      'uvi': 0.18,
#      'clouds': 100,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 54,
#      'wind_gust': 3.13,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632592800,
#      'temp': 17.36,
#      'feels_like': 17.48,
#      'pressure': 1014,
#      'humidity': 89,
#      'dew_point': 15.53,
#      'uvi': 0,
#      'clouds': 92,
#      'visibility': 10000,
#      'wind_speed': 6.26,
#      'wind_deg': 320,
#      'wind_gust': 10.28,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632596400,
#      'temp': 16.21,
#      'feels_like': 16.37,
#      'pressure': 1014,
#      'humidity': 95,
#      'dew_point': 15.41,
#      'uvi': 0,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 80,
#      'wind_gust': 3.13,
#      'weather': [{'id': 502,
#        'main': 'Rain',
#        'description': 'heavy intensity rain',
#        'icon': '10n'}],
#      'rain': {'1h': 6.86}},
#     {'dt': 1632600000,
#      'temp': 16.35,
#      'feels_like': 16.57,
#      'pressure': 1014,
#      'humidity': 97,
#      'dew_point': 15.87,
#      'uvi': 0,
#      'clouds': 99,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 140,
#      'wind_gust': 2.68,
#      'weather': [{'id': 501,
#        'main': 'Rain',
#        'description': 'moderate rain',
#        'icon': '10n'}],
#      'rain': {'1h': 2.29}},
#     {'dt': 1632603600,
#      'temp': 16.09,
#      'feels_like': 16.34,
#      'pressure': 1015,
#      'humidity': 99,
#      'dew_point': 15.93,
#      'uvi': 0,
#      'clouds': 96,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 140,
#      'wind_gust': 1.34,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632607200,
#      'temp': 15.07,
#      'feels_like': 15.19,
#      'pressure': 1016,
#      'humidity': 98,
#      'dew_point': 14.76,
#      'uvi': 0,
#      'clouds': 81,
#      'visibility': 10000,
#      'wind_speed': 1.69,
#      'wind_deg': 201,
#      'wind_gust': 1.64,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632610800,
#      'temp': 14.92,
#      'feels_like': 15.05,
#      'pressure': 1016,
#      'humidity': 99,
#      'dew_point': 14.76,
#      'uvi': 0,
#      'clouds': 69,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 190,
#      'wind_gust': 2.24,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]}]}},
#  {'city': 'Barcelona',
#   'data': {'lat': 41.3831,
#    'lon': 2.178,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632548506,
#     'sunset': 1632591845,
#     'temp': 21.92,
#     'feels_like': 22.31,
#     'pressure': 1015,
#     'humidity': 82,
#     'dew_point': 18.71,
#     'uvi': 0,
#     'clouds': 75,
#     'visibility': 10000,
#     'wind_speed': 2.06,
#     'wind_deg': 40,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 21.92,
#      'feels_like': 22.31,
#      'pressure': 1015,
#      'humidity': 82,
#      'dew_point': 18.71,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 40,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632531600,
#      'temp': 21.79,
#      'feels_like': 22.19,
#      'pressure': 1016,
#      'humidity': 83,
#      'dew_point': 18.78,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 286,
#      'wind_gust': 0.89,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632535200,
#      'temp': 22.05,
#      'feels_like': 22.45,
#      'pressure': 1016,
#      'humidity': 82,
#      'dew_point': 18.84,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 3.09,
#      'wind_deg': 350,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632538800,
#      'temp': 21.8,
#      'feels_like': 22.23,
#      'pressure': 1015,
#      'humidity': 84,
#      'dew_point': 18.98,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 136,
#      'wind_gust': 0.89,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632542400,
#      'temp': 21.86,
#      'feels_like': 22.29,
#      'pressure': 1016,
#      'humidity': 84,
#      'dew_point': 19.04,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 165,
#      'wind_gust': 0.89,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632546000,
#      'temp': 21.78,
#      'feels_like': 22.23,
#      'pressure': 1016,
#      'humidity': 85,
#      'dew_point': 19.15,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 109,
#      'wind_gust': 0.45,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.29}},
#     {'dt': 1632549600,
#      'temp': 21.66,
#      'feels_like': 22.1,
#      'pressure': 1015,
#      'humidity': 85,
#      'dew_point': 19.03,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 321,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632553200,
#      'temp': 21.87,
#      'feels_like': 22.28,
#      'pressure': 1015,
#      'humidity': 83,
#      'dew_point': 18.85,
#      'uvi': 0.26,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 271,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632556800,
#      'temp': 23.8,
#      'feels_like': 24.25,
#      'pressure': 1016,
#      'humidity': 77,
#      'dew_point': 19.53,
#      'uvi': 0.94,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 2.24,
#      'wind_deg': 317,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632560400,
#      'temp': 25.31,
#      'feels_like': 25.78,
#      'pressure': 1016,
#      'humidity': 72,
#      'dew_point': 19.9,
#      'uvi': 2.04,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 252,
#      'wind_gust': 3.58,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632564000,
#      'temp': 26.56,
#      'feels_like': 26.56,
#      'pressure': 1016,
#      'humidity': 70,
#      'dew_point': 20.64,
#      'uvi': 3.96,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 156,
#      'wind_gust': 3.13,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632567600,
#      'temp': 27.36,
#      'feels_like': 29.48,
#      'pressure': 1016,
#      'humidity': 70,
#      'dew_point': 21.41,
#      'uvi': 5.11,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 76,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632571200,
#      'temp': 27.38,
#      'feels_like': 30.04,
#      'pressure': 1016,
#      'humidity': 75,
#      'dew_point': 22.56,
#      'uvi': 5.46,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 179,
#      'wind_gust': 4.02,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632574800,
#      'temp': 27.01,
#      'feels_like': 29.58,
#      'pressure': 1016,
#      'humidity': 78,
#      'dew_point': 22.84,
#      'uvi': 4.84,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 134,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632578400,
#      'temp': 26.81,
#      'feels_like': 29.24,
#      'pressure': 1015,
#      'humidity': 79,
#      'dew_point': 22.86,
#      'uvi': 3.56,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 192,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632582000,
#      'temp': 26.47,
#      'feels_like': 26.47,
#      'pressure': 1015,
#      'humidity': 81,
#      'dew_point': 22.94,
#      'uvi': 2.05,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 143,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632585600,
#      'temp': 25.97,
#      'feels_like': 25.97,
#      'pressure': 1015,
#      'humidity': 82,
#      'dew_point': 22.66,
#      'uvi': 0.84,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 189,
#      'wind_gust': 4.02,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632589200,
#      'temp': 25.81,
#      'feels_like': 26.56,
#      'pressure': 1015,
#      'humidity': 81,
#      'dew_point': 22.3,
#      'uvi': 0.2,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 253,
#      'wind_gust': 3.58,
#      'weather': [{'id': 300,
#        'main': 'Drizzle',
#        'description': 'light intensity drizzle',
#        'icon': '09d'}]},
#     {'dt': 1632592800,
#      'temp': 24.9,
#      'feels_like': 25.61,
#      'pressure': 1015,
#      'humidity': 83,
#      'dew_point': 21.81,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 261,
#      'wind_gust': 1.79,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632596400,
#      'temp': 24.53,
#      'feels_like': 25.26,
#      'pressure': 1016,
#      'humidity': 85,
#      'dew_point': 21.84,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.51,
#      'wind_deg': 270,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632600000,
#      'temp': 24.09,
#      'feels_like': 24.72,
#      'pressure': 1016,
#      'humidity': 83,
#      'dew_point': 21.02,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 294,
#      'weather': [{'id': 200,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm with light rain',
#        'icon': '11n'}]},
#     {'dt': 1632603600,
#      'temp': 23.88,
#      'feels_like': 24.54,
#      'pressure': 1016,
#      'humidity': 85,
#      'dew_point': 21.2,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.03,
#      'wind_deg': 0,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632607200,
#      'temp': 23.39,
#      'feels_like': 24,
#      'pressure': 1016,
#      'humidity': 85,
#      'dew_point': 20.72,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 200,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632610800,
#      'temp': 23.11,
#      'feels_like': 23.77,
#      'pressure': 1016,
#      'humidity': 88,
#      'dew_point': 21.01,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 3.6,
#      'wind_deg': 240,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]}]}},
#  {'city': 'Valencia',
#   'data': {'lat': 39.4704,
#    'lon': -0.3753,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632549114,
#     'sunset': 1632592463,
#     'temp': 21.14,
#     'feels_like': 21.66,
#     'pressure': 1014,
#     'humidity': 90,
#     'dew_point': 19.44,
#     'uvi': 0,
#     'clouds': 20,
#     'visibility': 10000,
#     'wind_speed': 0.45,
#     'wind_deg': 154,
#     'wind_gust': 1.79,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 21.14,
#      'feels_like': 21.66,
#      'pressure': 1014,
#      'humidity': 90,
#      'dew_point': 19.44,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 154,
#      'wind_gust': 1.79,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632531600,
#      'temp': 21.03,
#      'feels_like': 21.62,
#      'pressure': 1014,
#      'humidity': 93,
#      'dew_point': 19.85,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 336,
#      'wind_gust': 1.79,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632535200,
#      'temp': 21.1,
#      'feels_like': 21.69,
#      'pressure': 1014,
#      'humidity': 93,
#      'dew_point': 19.92,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 197,
#      'wind_gust': 2.68,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632538800,
#      'temp': 21.12,
#      'feels_like': 21.74,
#      'pressure': 1014,
#      'humidity': 94,
#      'dew_point': 20.12,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 190,
#      'wind_gust': 1.34,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632542400,
#      'temp': 21.17,
#      'feels_like': 21.77,
#      'pressure': 1013,
#      'humidity': 93,
#      'dew_point': 19.99,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 202,
#      'wind_gust': 1.34,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632546000,
#      'temp': 21.3,
#      'feels_like': 21.89,
#      'pressure': 1014,
#      'humidity': 92,
#      'dew_point': 19.95,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 0,
#      'wind_gust': 1.34,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632549600,
#      'temp': 20.9,
#      'feels_like': 21.47,
#      'pressure': 1014,
#      'humidity': 93,
#      'dew_point': 19.73,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 196,
#      'wind_gust': 2.24,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.11}},
#     {'dt': 1632553200,
#      'temp': 21.22,
#      'feels_like': 21.83,
#      'pressure': 1015,
#      'humidity': 93,
#      'dew_point': 20.04,
#      'uvi': 0.25,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 169,
#      'wind_gust': 1.34,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632556800,
#      'temp': 22.91,
#      'feels_like': 23.48,
#      'pressure': 1015,
#      'humidity': 85,
#      'dew_point': 20.25,
#      'uvi': 1.01,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 198,
#      'wind_gust': 1.79,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.28}},
#     {'dt': 1632560400,
#      'temp': 24.41,
#      'feels_like': 24.94,
#      'pressure': 1015,
#      'humidity': 78,
#      'dew_point': 20.33,
#      'uvi': 2.35,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 264,
#      'wind_gust': 4.02,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.65}},
#     {'dt': 1632564000,
#      'temp': 25.26,
#      'feels_like': 25.8,
#      'pressure': 1016,
#      'humidity': 75,
#      'dew_point': 20.51,
#      'uvi': 3.9,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 161,
#      'wind_gust': 3.13,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.45}},
#     {'dt': 1632567600,
#      'temp': 26,
#      'feels_like': 26,
#      'pressure': 1015,
#      'humidity': 73,
#      'dew_point': 20.79,
#      'uvi': 5.21,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 152,
#      'wind_gust': 2.24,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632571200,
#      'temp': 27.57,
#      'feels_like': 29.12,
#      'pressure': 1015,
#      'humidity': 63,
#      'dew_point': 19.9,
#      'uvi': 5.75,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 119,
#      'wind_gust': 3.58,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632574800,
#      'temp': 27.26,
#      'feels_like': 29.11,
#      'pressure': 1015,
#      'humidity': 68,
#      'dew_point': 20.84,
#      'uvi': 5.22,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 4.47,
#      'wind_deg': 118,
#      'wind_gust': 7.6,
#      'weather': [{'id': 211,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm',
#        'icon': '11d'}]},
#     {'dt': 1632578400,
#      'temp': 26.6,
#      'feels_like': 26.6,
#      'pressure': 1014,
#      'humidity': 70,
#      'dew_point': 20.68,
#      'uvi': 3.96,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 137,
#      'wind_gust': 2.68,
#      'weather': [{'id': 200,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm with light rain',
#        'icon': '11d'}]},
#     {'dt': 1632582000,
#      'temp': 27.35,
#      'feels_like': 29.17,
#      'pressure': 1014,
#      'humidity': 67,
#      'dew_point': 20.68,
#      'uvi': 2.39,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 2.24,
#      'wind_deg': 90,
#      'wind_gust': 4.02,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632585600,
#      'temp': 25.93,
#      'feels_like': 26.48,
#      'pressure': 1013,
#      'humidity': 73,
#      'dew_point': 20.72,
#      'uvi': 0.98,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 3.13,
#      'wind_deg': 54,
#      'wind_gust': 4.92,
#      'weather': [{'id': 200,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm with light rain',
#        'icon': '11d'}]},
#     {'dt': 1632589200,
#      'temp': 24.17,
#      'feels_like': 24.86,
#      'pressure': 1014,
#      'humidity': 85,
#      'dew_point': 21.49,
#      'uvi': 0.25,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 3.58,
#      'wind_deg': 90,
#      'wind_gust': 4.92,
#      'weather': [{'id': 520,
#        'main': 'Rain',
#        'description': 'light intensity shower rain',
#        'icon': '09d'}],
#      'rain': {'1h': 0.51}},
#     {'dt': 1632592800,
#      'temp': 23.42,
#      'feels_like': 24.17,
#      'pressure': 1014,
#      'humidity': 90,
#      'dew_point': 21.69,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 175,
#      'wind_gust': 1.79,
#      'weather': [{'id': 200,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm with light rain',
#        'icon': '11n'},
#       {'id': 501,
#        'main': 'Rain',
#        'description': 'moderate rain',
#        'icon': '10n'}],
#      'rain': {'1h': 1.23}},
#     {'dt': 1632596400,
#      'temp': 23.02,
#      'feels_like': 23.75,
#      'pressure': 1015,
#      'humidity': 91,
#      'dew_point': 21.47,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 222,
#      'wind_gust': 2.24,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632600000,
#      'temp': 22.29,
#      'feels_like': 22.95,
#      'pressure': 1015,
#      'humidity': 91,
#      'dew_point': 20.75,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 283,
#      'wind_gust': 2.68,
#      'weather': [{'id': 501,
#        'main': 'Rain',
#        'description': 'moderate rain',
#        'icon': '10n'}],
#      'rain': {'1h': 1.4}},
#     {'dt': 1632603600,
#      'temp': 21.79,
#      'feels_like': 22.37,
#      'pressure': 1015,
#      'humidity': 90,
#      'dew_point': 20.08,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 221,
#      'wind_gust': 1.79,
#      'weather': [{'id': 701,
#        'main': 'Mist',
#        'description': 'mist',
#        'icon': '50n'}]},
#     {'dt': 1632607200,
#      'temp': 21.5,
#      'feels_like': 22.06,
#      'pressure': 1016,
#      'humidity': 90,
#      'dew_point': 19.79,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 210,
#      'wind_gust': 2.24,
#      'weather': [{'id': 701,
#        'main': 'Mist',
#        'description': 'mist',
#        'icon': '50n'}]},
#     {'dt': 1632610800,
#      'temp': 21.02,
#      'feels_like': 21.53,
#      'pressure': 1016,
#      'humidity': 90,
#      'dew_point': 19.32,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 176,
#      'wind_gust': 2.24,
#      'weather': [{'id': 701,
#        'main': 'Mist',
#        'description': 'mist',
#        'icon': '50n'}]}]}},
#  {'city': 'Toledo',
#   'data': {'lat': 39.8561,
#    'lon': -4.024,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632549991,
#     'sunset': 1632593336,
#     'temp': 19.53,
#     'feels_like': 19.68,
#     'pressure': 1015,
#     'humidity': 82,
#     'dew_point': 16.38,
#     'uvi': 0,
#     'clouds': 26,
#     'visibility': 10000,
#     'wind_speed': 1.34,
#     'wind_deg': 218,
#     'wind_gust': 1.42,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 19.53,
#      'feels_like': 19.68,
#      'pressure': 1015,
#      'humidity': 82,
#      'dew_point': 16.38,
#      'uvi': 0,
#      'clouds': 26,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 218,
#      'wind_gust': 1.42,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632531600,
#      'temp': 20.15,
#      'feels_like': 19.81,
#      'pressure': 1015,
#      'humidity': 61,
#      'dew_point': 12.4,
#      'uvi': 0,
#      'clouds': 31,
#      'visibility': 10000,
#      'wind_speed': 1.94,
#      'wind_deg': 196,
#      'wind_gust': 2.05,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632535200,
#      'temp': 20.6,
#      'feels_like': 20.31,
#      'pressure': 1015,
#      'humidity': 61,
#      'dew_point': 12.82,
#      'uvi': 0,
#      'clouds': 18,
#      'visibility': 10000,
#      'wind_speed': 2.67,
#      'wind_deg': 194,
#      'wind_gust': 3.08,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632538800,
#      'temp': 20.05,
#      'feels_like': 19.7,
#      'pressure': 1016,
#      'humidity': 61,
#      'dew_point': 12.31,
#      'uvi': 0,
#      'clouds': 12,
#      'visibility': 10000,
#      'wind_speed': 3.12,
#      'wind_deg': 192,
#      'wind_gust': 3.9,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632542400,
#      'temp': 18.19,
#      'feels_like': 18.1,
#      'pressure': 1016,
#      'humidity': 78,
#      'dew_point': 14.29,
#      'uvi': 0,
#      'clouds': 9,
#      'visibility': 10000,
#      'wind_speed': 2.99,
#      'wind_deg': 191,
#      'wind_gust': 3.49,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632546000,
#      'temp': 16.44,
#      'feels_like': 16.12,
#      'pressure': 1017,
#      'humidity': 76,
#      'dew_point': 12.2,
#      'uvi': 0,
#      'clouds': 8,
#      'visibility': 10000,
#      'wind_speed': 2.83,
#      'wind_deg': 191,
#      'wind_gust': 3.09,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632549600,
#      'temp': 16.11,
#      'feels_like': 15.81,
#      'pressure': 1017,
#      'humidity': 78,
#      'dew_point': 12.28,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.98,
#      'wind_deg': 198,
#      'wind_gust': 3.05,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632553200,
#      'temp': 16.31,
#      'feels_like': 16.03,
#      'pressure': 1018,
#      'humidity': 78,
#      'dew_point': 12.47,
#      'uvi': 0.15,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.57,
#      'wind_deg': 199,
#      'wind_gust': 4.05,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632556800,
#      'temp': 18.08,
#      'feels_like': 17.51,
#      'pressure': 1018,
#      'humidity': 60,
#      'dew_point': 10.2,
#      'uvi': 0.73,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.95,
#      'wind_deg': 201,
#      'wind_gust': 4.06,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632560400,
#      'temp': 18.7,
#      'feels_like': 18.14,
#      'pressure': 1018,
#      'humidity': 58,
#      'dew_point': 10.28,
#      'uvi': 1.88,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 3.14,
#      'wind_deg': 223,
#      'wind_gust': 4.47,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632564000,
#      'temp': 18.25,
#      'feels_like': 17.65,
#      'pressure': 1018,
#      'humidity': 58,
#      'dew_point': 9.86,
#      'uvi': 3.26,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 3.82,
#      'wind_deg': 243,
#      'wind_gust': 4.91,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632567600,
#      'temp': 18.72,
#      'feels_like': 18.06,
#      'pressure': 1018,
#      'humidity': 54,
#      'dew_point': 9.23,
#      'uvi': 4.6,
#      'clouds': 1,
#      'visibility': 10000,
#      'wind_speed': 4.27,
#      'wind_deg': 240,
#      'wind_gust': 5.59,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632571200,
#      'temp': 22.03,
#      'feels_like': 21.72,
#      'pressure': 1018,
#      'humidity': 55,
#      'dew_point': 12.58,
#      'uvi': 5.32,
#      'clouds': 43,
#      'visibility': 10000,
#      'wind_speed': 4.88,
#      'wind_deg': 235,
#      'wind_gust': 6.65,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632574800,
#      'temp': 22.2,
#      'feels_like': 21.83,
#      'pressure': 1017,
#      'humidity': 52,
#      'dew_point': 11.89,
#      'uvi': 5.16,
#      'clouds': 51,
#      'visibility': 10000,
#      'wind_speed': 5.45,
#      'wind_deg': 238,
#      'wind_gust': 7.28,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1632578400,
#      'temp': 22.94,
#      'feels_like': 22.6,
#      'pressure': 1017,
#      'humidity': 50,
#      'dew_point': 11.97,
#      'uvi': 4.14,
#      'clouds': 49,
#      'visibility': 10000,
#      'wind_speed': 6.27,
#      'wind_deg': 239,
#      'wind_gust': 7.57,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632582000,
#      'temp': 23.49,
#      'feels_like': 23.17,
#      'pressure': 1016,
#      'humidity': 49,
#      'dew_point': 12.17,
#      'uvi': 2.67,
#      'clouds': 48,
#      'visibility': 10000,
#      'wind_speed': 6.58,
#      'wind_deg': 242,
#      'wind_gust': 7.63,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632585600,
#      'temp': 23.48,
#      'feels_like': 23.16,
#      'pressure': 1016,
#      'humidity': 49,
#      'dew_point': 12.16,
#      'uvi': 0.71,
#      'clouds': 51,
#      'visibility': 10000,
#      'wind_speed': 7.04,
#      'wind_deg': 244,
#      'wind_gust': 7.59,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1632589200,
#      'temp': 21,
#      'feels_like': 20.43,
#      'pressure': 1018,
#      'humidity': 49,
#      'dew_point': 9.89,
#      'uvi': 0.22,
#      'clouds': 50,
#      'visibility': 10000,
#      'wind_speed': 6.99,
#      'wind_deg': 249,
#      'wind_gust': 7.5,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632592800,
#      'temp': 19.82,
#      'feels_like': 19.35,
#      'pressure': 1018,
#      'humidity': 57,
#      'dew_point': 11.06,
#      'uvi': 0,
#      'clouds': 5,
#      'visibility': 10000,
#      'wind_speed': 5.8,
#      'wind_deg': 251,
#      'wind_gust': 8.42,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632596400,
#      'temp': 20.56,
#      'feels_like': 20.34,
#      'pressure': 1019,
#      'humidity': 64,
#      'dew_point': 13.52,
#      'uvi': 0,
#      'clouds': 11,
#      'visibility': 10000,
#      'wind_speed': 3.92,
#      'wind_deg': 246,
#      'wind_gust': 6.96,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632600000,
#      'temp': 17.51,
#      'feels_like': 17.07,
#      'pressure': 1020,
#      'humidity': 67,
#      'dew_point': 11.32,
#      'uvi': 0,
#      'clouds': 9,
#      'visibility': 10000,
#      'wind_speed': 3.4,
#      'wind_deg': 249,
#      'wind_gust': 6.1,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632603600,
#      'temp': 18.73,
#      'feels_like': 18.43,
#      'pressure': 1020,
#      'humidity': 68,
#      'dew_point': 12.71,
#      'uvi': 0,
#      'clouds': 6,
#      'visibility': 10000,
#      'wind_speed': 3.03,
#      'wind_deg': 252,
#      'wind_gust': 5.23,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632607200,
#      'temp': 19.22,
#      'feels_like': 19.03,
#      'pressure': 1020,
#      'humidity': 70,
#      'dew_point': 13.62,
#      'uvi': 0,
#      'clouds': 5,
#      'visibility': 10000,
#      'wind_speed': 2.54,
#      'wind_deg': 254,
#      'wind_gust': 3.81,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632610800,
#      'temp': 16.36,
#      'feels_like': 15.91,
#      'pressure': 1020,
#      'humidity': 71,
#      'dew_point': 11.1,
#      'uvi': 0,
#      'clouds': 4,
#      'visibility': 10000,
#      'wind_speed': 2.07,
#      'wind_deg': 240,
#      'wind_gust': 2.97,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]}]}},
#  {'city': 'Valladolid',
#   'data': {'lat': 41.6521,
#    'lon': -4.7286,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632550166,
#     'sunset': 1632593500,
#     'temp': 14.28,
#     'feels_like': 14.19,
#     'pressure': 1014,
#     'humidity': 93,
#     'dew_point': 13.16,
#     'uvi': 0,
#     'clouds': 0,
#     'visibility': 10000,
#     'wind_speed': 1.54,
#     'wind_deg': 200,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'clear sky',
#       'icon': '01n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 14.28,
#      'feels_like': 14.19,
#      'pressure': 1014,
#      'humidity': 93,
#      'dew_point': 13.16,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 200,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632531600,
#      'temp': 14.05,
#      'feels_like': 13.89,
#      'pressure': 1015,
#      'humidity': 91,
#      'dew_point': 12.6,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 220,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632535200,
#      'temp': 14.79,
#      'feels_like': 14.49,
#      'pressure': 1015,
#      'humidity': 83,
#      'dew_point': 11.93,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 180,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632538800,
#      'temp': 14.95,
#      'feels_like': 14.56,
#      'pressure': 1015,
#      'humidity': 79,
#      'dew_point': 11.34,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 170,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632542400,
#      'temp': 13.64,
#      'feels_like': 13.28,
#      'pressure': 1014,
#      'humidity': 85,
#      'dew_point': 11.17,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 257,
#      'wind_gust': 1.34,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632546000,
#      'temp': 12.56,
#      'feels_like': 12.14,
#      'pressure': 1015,
#      'humidity': 87,
#      'dew_point': 10.46,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.57,
#      'wind_deg': 160,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632549600,
#      'temp': 13,
#      'feels_like': 12.52,
#      'pressure': 1015,
#      'humidity': 83,
#      'dew_point': 10.18,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 220,
#      'wind_gust': 0.45,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632553200,
#      'temp': 13.06,
#      'feels_like': 12.61,
#      'pressure': 1015,
#      'humidity': 84,
#      'dew_point': 10.42,
#      'uvi': 0.11,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 190,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632556800,
#      'temp': 13.23,
#      'feels_like': 12.91,
#      'pressure': 1016,
#      'humidity': 88,
#      'dew_point': 11.29,
#      'uvi': 0.58,
#      'clouds': 75,
#      'visibility': 5000,
#      'wind_speed': 0.89,
#      'wind_deg': 229,
#      'wind_gust': 1.79,
#      'weather': [{'id': 520,
#        'main': 'Rain',
#        'description': 'light intensity shower rain',
#        'icon': '09d'}],
#      'rain': {'1h': 0.51}},
#     {'dt': 1632560400,
#      'temp': 17.25,
#      'feels_like': 16.94,
#      'pressure': 1019,
#      'humidity': 73,
#      'dew_point': 12.37,
#      'uvi': 1.49,
#      'clouds': 40,
#      'visibility': 9000,
#      'wind_speed': 3.09,
#      'wind_deg': 240,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.27}},
#     {'dt': 1632564000,
#      'temp': 18.36,
#      'feels_like': 18.13,
#      'pressure': 1019,
#      'humidity': 72,
#      'dew_point': 13.23,
#      'uvi': 3.01,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 240,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.3}},
#     {'dt': 1632567600,
#      'temp': 18.18,
#      'feels_like': 17.91,
#      'pressure': 1018,
#      'humidity': 71,
#      'dew_point': 12.84,
#      'uvi': 4.28,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 4.12,
#      'wind_deg': 220,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632571200,
#      'temp': 19.51,
#      'feels_like': 19.03,
#      'pressure': 1017,
#      'humidity': 58,
#      'dew_point': 11.04,
#      'uvi': 4.97,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 8.23,
#      'wind_deg': 220,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632574800,
#      'temp': 19.37,
#      'feels_like': 18.93,
#      'pressure': 1017,
#      'humidity': 60,
#      'dew_point': 11.42,
#      'uvi': 1.31,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 3.13,
#      'wind_deg': 217,
#      'wind_gust': 9.39,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632578400,
#      'temp': 18.69,
#      'feels_like': 18.29,
#      'pressure': 1016,
#      'humidity': 64,
#      'dew_point': 11.75,
#      'uvi': 1.06,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 259,
#      'wind_gust': 2.68,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632582000,
#      'temp': 18.69,
#      'feels_like': 18.34,
#      'pressure': 1017,
#      'humidity': 66,
#      'dew_point': 12.22,
#      'uvi': 0.69,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 231,
#      'wind_gust': 4.02,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}]},
#     {'dt': 1632585600,
#      'temp': 18.91,
#      'feels_like': 18.79,
#      'pressure': 1020,
#      'humidity': 74,
#      'dew_point': 14.18,
#      'uvi': 1.09,
#      'clouds': 75,
#      'visibility': 4000,
#      'wind_speed': 4.63,
#      'wind_deg': 250,
#      'weather': [{'id': 501,
#        'main': 'Rain',
#        'description': 'moderate rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.12}},
#     {'dt': 1632589200,
#      'temp': 16.07,
#      'feels_like': 15.98,
#      'pressure': 1020,
#      'humidity': 86,
#      'dew_point': 13.73,
#      'uvi': 0.36,
#      'clouds': 90,
#      'visibility': 10000,
#      'wind_speed': 4.63,
#      'wind_deg': 250,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.3}},
#     {'dt': 1632592800,
#      'temp': 14.53,
#      'feels_like': 14.39,
#      'pressure': 1017,
#      'humidity': 90,
#      'dew_point': 12.91,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 227,
#      'wind_gust': 1.79,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.25}},
#     {'dt': 1632596400,
#      'temp': 14.71,
#      'feels_like': 14.61,
#      'pressure': 1018,
#      'humidity': 91,
#      'dew_point': 13.26,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 260,
#      'wind_gust': 2.68,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.2}},
#     {'dt': 1632600000,
#      'temp': 14.78,
#      'feels_like': 14.72,
# ...
#      'wind_deg': 0,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632556800,
#      'temp': 17.23,
#      'feels_like': 17.54,
#      'pressure': 1017,
#      'humidity': 97,
#      'dew_point': 16.75,
#      'uvi': 0.66,
#      'clouds': 90,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 130,
#      'weather': [{'id': 804,
#        'main': 'Clouds',
#        'description': 'overcast clouds',
#        'icon': '04d'}]},
#     {'dt': 1632560400,
#      'temp': 18.37,
#      'feels_like': 18.72,
#      'pressure': 1017,
#      'humidity': 94,
#      'dew_point': 17.39,
#      'uvi': 1.61,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 1.03,
#      'wind_deg': 0,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1632564000,
#      'temp': 20.66,
#      'feels_like': 21.18,
#      'pressure': 1016,
#      'humidity': 92,
#      'dew_point': 19.31,
#      'uvi': 3.4,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 230,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632567600,
#      'temp': 22.88,
#      'feels_like': 23.44,
#      'pressure': 1016,
#      'humidity': 85,
#      'dew_point': 20.22,
#      'uvi': 4.66,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 100,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632571200,
#      'temp': 23.1,
#      'feels_like': 24.08,
#      'pressure': 1015,
#      'humidity': 100,
#      'dew_point': 23.1,
#      'uvi': 5.25,
#      'clouds': 28,
#      'visibility': 10000,
#      'wind_speed': 2.96,
#      'wind_deg': 204,
#      'wind_gust': 6.02,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632574800,
#      'temp': 23.77,
#      'feels_like': 23.59,
#      'pressure': 1015,
#      'humidity': 53,
#      'dew_point': 13.63,
#      'uvi': 4.53,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 4.12,
#      'wind_deg': 260,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02d'}]},
#     {'dt': 1632578400,
#      'temp': 23.74,
#      'feels_like': 23.37,
#      'pressure': 1015,
#      'humidity': 46,
#      'dew_point': 11.44,
#      'uvi': 3.54,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 4.12,
#      'wind_deg': 260,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632582000,
#      'temp': 23.56,
#      'feels_like': 23.28,
#      'pressure': 1015,
#      'humidity': 50,
#      'dew_point': 12.54,
#      'uvi': 2.21,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 5.66,
#      'wind_deg': 280,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632585600,
#      'temp': 22.56,
#      'feels_like': 22.86,
#      'pressure': 1015,
#      'humidity': 76,
#      'dew_point': 18.12,
#      'uvi': 0.51,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.57,
#      'wind_deg': 290,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632589200,
#      'temp': 21.78,
#      'feels_like': 22.05,
#      'pressure': 1015,
#      'humidity': 78,
#      'dew_point': 17.78,
#      'uvi': 0.15,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 310,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632592800,
#      'temp': 20.64,
#      'feels_like': 20.82,
#      'pressure': 1016,
#      'humidity': 79,
#      'dew_point': 16.87,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 300,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01d'}]},
#     {'dt': 1632596400,
#      'temp': 17.08,
#      'feels_like': 17.17,
#      'pressure': 1019,
#      'humidity': 89,
#      'dew_point': 15.25,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 7.72,
#      'wind_deg': 280,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632600000,
#      'temp': 17.04,
#      'feels_like': 17.12,
#      'pressure': 1019,
#      'humidity': 89,
#      'dew_point': 15.21,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 3.6,
#      'wind_deg': 250,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632603600,
#      'temp': 16.35,
#      'feels_like': 16.5,
#      'pressure': 1019,
#      'humidity': 94,
#      'dew_point': 15.38,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 260,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632607200,
#      'temp': 16.36,
#      'feels_like': 16.51,
#      'pressure': 1020,
#      'humidity': 94,
#      'dew_point': 15.39,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 2.06,
#      'wind_deg': 270,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632610800,
#      'temp': 16.36,
#      'feels_like': 16.51,
#      'pressure': 1020,
#      'humidity': 94,
#      'dew_point': 15.39,
#      'uvi': 0,
#      'clouds': 0,
#      'visibility': 10000,
#      'wind_speed': 1.54,
#      'wind_deg': 280,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]}]}},
#  {'city': 'Vitoria-gasteiz',
#   'data': {'lat': 42.8488,
#    'lon': -2.6711,
#    'timezone': 'Europe/Madrid',
#    'timezone_offset': 7200,
#    'current': {'dt': 1632528000,
#     'sunrise': 1632549675,
#     'sunset': 1632593003,
#     'temp': 17.61,
#     'feels_like': 17.62,
#     'pressure': 1018,
#     'humidity': 84,
#     'dew_point': 14.88,
#     'uvi': 0,
#     'clouds': 20,
#     'visibility': 10000,
#     'wind_speed': 3.13,
#     'wind_deg': 135,
#     'wind_gust': 3.58,
#     'weather': [{'id': 211,
#       'main': 'Thunderstorm',
#       'description': 'thunderstorm',
#       'icon': '11n'},
#      {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}]},
#    'hourly': [{'dt': 1632528000,
#      'temp': 17.61,
#      'feels_like': 17.62,
#      'pressure': 1018,
#      'humidity': 84,
#      'dew_point': 14.88,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 10000,
#      'wind_speed': 3.13,
#      'wind_deg': 135,
#      'wind_gust': 3.58,
#      'weather': [{'id': 211,
#        'main': 'Thunderstorm',
#        'description': 'thunderstorm',
#        'icon': '11n'},
#       {'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10n'}]},
#     {'dt': 1632531600,
#      'temp': 16.9,
#      'feels_like': 16.97,
#      'pressure': 1016,
#      'humidity': 89,
#      'dew_point': 15.08,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 157,
#      'wind_gust': 1.79,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632535200,
#      'temp': 16.53,
#      'feels_like': 16.54,
#      'pressure': 1017,
#      'humidity': 88,
#      'dew_point': 14.54,
#      'uvi': 0,
#      'clouds': 3,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 124,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632538800,
#      'temp': 15.6,
#      'feels_like': 15.57,
#      'pressure': 1018,
#      'humidity': 90,
#      'dew_point': 13.97,
#      'uvi': 0,
#      'clouds': 7,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 315,
#      'wind_gust': 2.24,
#      'weather': [{'id': 800,
#        'main': 'Clear',
#        'description': 'clear sky',
#        'icon': '01n'}]},
#     {'dt': 1632542400,
#      'temp': 15.86,
#      'feels_like': 15.88,
#      'pressure': 1017,
#      'humidity': 91,
#      'dew_point': 14.39,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 6000,
#      'wind_speed': 1.34,
#      'wind_deg': 292,
#      'wind_gust': 1.79,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632546000,
#      'temp': 15.67,
#      'feels_like': 15.72,
#      'pressure': 1016,
#      'humidity': 93,
#      'dew_point': 14.54,
#      'uvi': 0,
#      'clouds': 20,
#      'visibility': 6000,
#      'wind_speed': 1.34,
#      'wind_deg': 292,
#      'wind_gust': 1.79,
#      'weather': [{'id': 801,
#        'main': 'Clouds',
#        'description': 'few clouds',
#        'icon': '02n'}]},
#     {'dt': 1632549600,
#      'temp': 15.06,
#      'feels_like': 15.05,
#      'pressure': 1016,
#      'humidity': 93,
#      'dew_point': 13.94,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 6000,
#      'wind_speed': 1.03,
#      'wind_deg': 0,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632553200,
#      'temp': 14.96,
#      'feels_like': 14.94,
#      'pressure': 1016,
#      'humidity': 93,
#      'dew_point': 13.84,
#      'uvi': 0.18,
#      'clouds': 40,
#      'visibility': 7000,
#      'wind_speed': 1.03,
#      'wind_deg': 270,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632556800,
#      'temp': 17.33,
#      'feels_like': 17.44,
#      'pressure': 1016,
#      'humidity': 89,
#      'dew_point': 15.5,
#      'uvi': 0.76,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.51,
#      'wind_deg': 0,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632560400,
#      'temp': 19.28,
#      'feels_like': 19.33,
#      'pressure': 1017,
#      'humidity': 79,
#      'dew_point': 15.55,
#      'uvi': 1.86,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 180,
#      'wind_gust': 1.79,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632564000,
#      'temp': 20.08,
#      'feels_like': 20.08,
#      'pressure': 1017,
#      'humidity': 74,
#      'dew_point': 15.31,
#      'uvi': 2.99,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 202,
#      'wind_gust': 1.34,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632567600,
#      'temp': 21.65,
#      'feels_like': 21.49,
#      'pressure': 1017,
#      'humidity': 62,
#      'dew_point': 14.06,
#      'uvi': 4.14,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 337,
#      'wind_gust': 4.02,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632571200,
#      'temp': 22.71,
#      'feels_like': 22.42,
#      'pressure': 1017,
#      'humidity': 53,
#      'dew_point': 12.65,
#      'uvi': 4.69,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 2.68,
#      'wind_deg': 135,
#      'wind_gust': 4.02,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632574800,
#      'temp': 22.95,
#      'feels_like': 22.66,
#      'pressure': 1019,
#      'humidity': 52,
#      'dew_point': 12.58,
#      'uvi': 2.87,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 4.92,
#      'wind_deg': 157,
#      'wind_gust': 8.05,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632578400,
#      'temp': 22.27,
#      'feels_like': 21.91,
#      'pressure': 1016,
#      'humidity': 52,
#      'dew_point': 11.95,
#      'uvi': 2.26,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 7.2,
#      'wind_deg': 220,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632582000,
#      'temp': 21.39,
#      'feels_like': 20.99,
#      'pressure': 1017,
#      'humidity': 54,
#      'dew_point': 11.71,
#      'uvi': 1.43,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 225,
#      'wind_gust': 3.13,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03d'}]},
#     {'dt': 1632585600,
#      'temp': 21.25,
#      'feels_like': 20.87,
#      'pressure': 1017,
#      'humidity': 55,
#      'dew_point': 11.86,
#      'uvi': 0.54,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 1.34,
#      'wind_deg': 292,
#      'wind_gust': 2.68,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04d'}]},
#     {'dt': 1632589200,
#      'temp': 19.91,
#      'feels_like': 19.6,
#      'pressure': 1018,
#      'humidity': 63,
#      'dew_point': 12.66,
#      'uvi': 0.16,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 315,
#      'wind_gust': 3.13,
#      'weather': [{'id': 521,
#        'main': 'Rain',
#        'description': 'shower rain',
#        'icon': '09d'}],
#      'rain': {'1h': 0.76}},
#     {'dt': 1632592800,
#      'temp': 17.64,
#      'feels_like': 17.37,
#      'pressure': 1019,
#      'humidity': 73,
#      'dew_point': 12.75,
#      'uvi': 0,
#      'clouds': 90,
#      'visibility': 10000,
#      'wind_speed': 5.36,
#      'wind_deg': 292,
#      'wind_gust': 8.05,
#      'weather': [{'id': 500,
#        'main': 'Rain',
#        'description': 'light rain',
#        'icon': '10d'}],
#      'rain': {'1h': 0.1}},
#     {'dt': 1632596400,
#      'temp': 15.26,
#      'feels_like': 14.96,
#      'pressure': 1019,
#      'humidity': 81,
#      'dew_point': 12.02,
#      'uvi': 0,
#      'clouds': 90,
#      'visibility': 5000,
#      'wind_speed': 0.89,
#      'wind_deg': 135,
#      'wind_gust': 1.79,
#      'weather': [{'id': 501,
#        'main': 'Rain',
#        'description': 'moderate rain',
#        'icon': '10n'}],
#      'rain': {'1h': 0.51}},
#     {'dt': 1632600000,
#      'temp': 14.73,
#      'feels_like': 14.48,
#      'pressure': 1019,
#      'humidity': 85,
#      'dew_point': 12.24,
#      'uvi': 0,
#      'clouds': 75,
#      'visibility': 10000,
#      'wind_speed': 2.24,
#      'wind_deg': 135,
#      'wind_gust': 3.13,
#      'weather': [{'id': 803,
#        'main': 'Clouds',
#        'description': 'broken clouds',
#        'icon': '04n'}]},
#     {'dt': 1632603600,
#      'temp': 14.86,
#      'feels_like': 14.57,
#      'pressure': 1020,
#      'humidity': 83,
#      'dew_point': 12,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 1.79,
#      'wind_deg': 112,
#      'wind_gust': 2.24,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632607200,
#      'temp': 14.97,
#      'feels_like': 14.69,
#      'pressure': 1020,
#      'humidity': 83,
#      'dew_point': 12.11,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.89,
#      'wind_deg': 135,
#      'wind_gust': 2.24,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]},
#     {'dt': 1632610800,
#      'temp': 14.98,
#      'feels_like': 14.73,
#      'pressure': 1021,
#      'humidity': 84,
#      'dew_point': 12.3,
#      'uvi': 0,
#      'clouds': 40,
#      'visibility': 10000,
#      'wind_speed': 0.45,
#      'wind_deg': 112,
#      'wind_gust': 0.89,
#      'weather': [{'id': 802,
#        'main': 'Clouds',
#        'description': 'scattered clouds',
#        'icon': '03n'}]}]}}]

# %% [markdown]
# Is the current timestamp the same as first hour?

# %%
for city in data:
    w = city['data']
    assert w['current']['dt'] == d['hourly'][0]['dt']

# %% [markdown]
# Getting the data we need:
# - Child element **summary** (parent: **weather**)
#     - attribute **mean_temp**: country’s mean temperature
#     - attribute **mean_wind_speed**: country’s mean wind speed
#     - attribute **coldest_place**: name of the city with the lowest mean temperature value
#     - attribute **warmest_place**: name of the city with the highest mean temperature value
#     - attribute **windiest_place**: name of the city with the highest mean wind speed value
#
#
# - For each city:
#     - attribute **mean_temp**: city’s mean temperature
#     - attribute **max_temp**: city’s max temperature
#     - attribute **min_temp**: city’s min temperature
#     - attribute **mean_wind_speed**: city’s mean wind speed
#     - attribute **max_wind_speed**: city’s max wind speed
#     - attribute **min_wind_speed**: city’s min wind speed

# %%
cdata = {}
for city, city_data in ((city['city'], city['data']) for city in data):
    temps = [h['temp'] for h in city_data['hourly']]
    tmin, tmax, tmean = min(temps), max(temps), round(mean(temps), 2)
    
    speeds = [h['wind_speed'] for h in city_data['hourly']]
    smin, smax, smean = min(speeds), max(speeds), round(mean(speeds), 2)
    
    cdata[city] = {
        'min_temp': tmin,
        'mean_temp': tmean,
        'max_temp': tmax,
        'min_wind_speed': smin,
        'mean_wind_speed': smean,
        'max_wind_speed': smax,

    }
cdata
# Out:
# {'Oviedo': {'min_temp': 14.26,
#   'mean_temp': 17.0,
#   'max_temp': 21.96,
#   'min_wind_speed': 0.17,
#   'mean_wind_speed': 1.54,
#   'max_wind_speed': 6.26},
#  'Barcelona': {'min_temp': 21.66,
#   'mean_temp': 24.21,
#   'max_temp': 27.38,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.26,
#   'max_wind_speed': 3.6},
#  'Valencia': {'min_temp': 20.9,
#   'mean_temp': 23.31,
#   'max_temp': 27.57,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.45,
#   'max_wind_speed': 4.47},
#  'Toledo': {'min_temp': 16.11,
#   'mean_temp': 19.52,
#   'max_temp': 23.49,
#   'min_wind_speed': 1.34,
#   'mean_wind_speed': 3.86,
#   'max_wind_speed': 7.04},
#  'Valladolid': {'min_temp': 12.56,
#   'mean_temp': 15.61,
#   'max_temp': 19.51,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 2.22,
#   'max_wind_speed': 8.23},
#  'Seville': {'min_temp': 17.24,
#   'mean_temp': 21.6,
#   'max_temp': 27.13,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.04,
#   'max_wind_speed': 2.24},
#  'Pamplona': {'min_temp': 16.01,
#   'mean_temp': 20.45,
#   'max_temp': 25.76,
#   'min_wind_speed': 0.51,
#   'mean_wind_speed': 4.03,
#   'max_wind_speed': 9.26},
#  'SantiagoDeCompostela': {'min_temp': 13.67,
#   'mean_temp': 16.18,
#   'max_temp': 19.84,
#   'min_wind_speed': 0,
#   'mean_wind_speed': 1.77,
#   'max_wind_speed': 4.02},
#  'Madrid': {'min_temp': 14.66,
#   'mean_temp': 17.89,
#   'max_temp': 21.35,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 2.65,
#   'max_wind_speed': 4.92},
#  'Merida': {'min_temp': 15.38,
#   'mean_temp': 19.53,
#   'max_temp': 24.54,
#   'min_wind_speed': 1.2,
#   'mean_wind_speed': 2.88,
#   'max_wind_speed': 4.62},
#  'Zaragoza': {'min_temp': 16.92,
#   'mean_temp': 21.16,
#   'max_temp': 26.61,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.8,
#   'max_wind_speed': 4.63},
#  'SantaCruzDeTenerife': {'min_temp': 19.63,
#   'mean_temp': 22.18,
#   'max_temp': 25.25,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.91,
#   'max_wind_speed': 4.02},
#  'Santander': {'min_temp': 16.92,
#   'mean_temp': 19.85,
#   'max_temp': 23.28,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 2.03,
#   'max_wind_speed': 4.02},
#  'Palma': {'min_temp': 22.91,
#   'mean_temp': 26.21,
#   'max_temp': 30.37,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.66,
#   'max_wind_speed': 6.26},
#  'Murcia': {'min_temp': 22.64,
#   'mean_temp': 25.64,
#   'max_temp': 30.26,
#   'min_wind_speed': 0.42,
#   'mean_wind_speed': 1.16,
#   'max_wind_speed': 4.02},
#  'Logrono': {'min_temp': 16.35,
#   'mean_temp': 19.13,
#   'max_temp': 23.77,
#   'min_wind_speed': 1.03,
#   'mean_wind_speed': 2.67,
#   'max_wind_speed': 7.72},
#  'Vitoria-gasteiz': {'min_temp': 14.73,
#   'mean_temp': 17.89,
#   'max_temp': 22.95,
#   'min_wind_speed': 0.45,
#   'mean_wind_speed': 1.99,
#   'max_wind_speed': 7.2}}

# %% [markdown]
# Computing the aggregates for all the cities (the 'summary' section)

# %%
temps = [c['mean_temp'] for c in cdata.values()]
tmean = round(mean(temps), 2)
speed = [c['mean_wind_speed'] for c in cdata.values()]
smean = round(mean(speeds), 2)

tmean, smean
# Out:
# (20.43, 1.99)

# %%
_, warmest_city = max([(dt['max_temp'], city) for city, dt in cdata.items()])
_, coldest_city = min([(dt['min_temp'], city) for city, dt in cdata.items()])
_, windiest_city = max([(dt['max_wind_speed'], city) for city, dt in cdata.items()])
warmest_city, coldest_city, windiest_city
# Out:
# ('Palma', 'Valladolid', 'Pamplona')

# %%
obj = {'summary': {
    'mean_temp': tmean,
    'mean_wind_speed': smean,
    'coldest_place': coldest_city,
    'warmest_place': warmest_city,
    'windiest_place': windiest_city
},
    'cities': cdata}
obj
# Out:
# {'summary': {'mean_temp': 20.43,
#   'mean_wind_speed': 1.99,
#   'coldest_place': 'Valladolid',
#   'warmest_place': 'Palma',
#   'windiest_place': 'Pamplona'},
#  'cities': {'Oviedo': {'min_temp': 14.26,
#    'mean_temp': 17.0,
#    'max_temp': 21.96,
#    'min_wind_speed': 0.17,
#    'mean_wind_speed': 1.54,
#    'max_wind_speed': 6.26},
#   'Barcelona': {'min_temp': 21.66,
#    'mean_temp': 24.21,
#    'max_temp': 27.38,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.26,
#    'max_wind_speed': 3.6},
#   'Valencia': {'min_temp': 20.9,
#    'mean_temp': 23.31,
#    'max_temp': 27.57,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.45,
#    'max_wind_speed': 4.47},
#   'Toledo': {'min_temp': 16.11,
#    'mean_temp': 19.52,
#    'max_temp': 23.49,
#    'min_wind_speed': 1.34,
#    'mean_wind_speed': 3.86,
#    'max_wind_speed': 7.04},
#   'Valladolid': {'min_temp': 12.56,
#    'mean_temp': 15.61,
#    'max_temp': 19.51,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 2.22,
#    'max_wind_speed': 8.23},
#   'Seville': {'min_temp': 17.24,
#    'mean_temp': 21.6,
#    'max_temp': 27.13,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.04,
#    'max_wind_speed': 2.24},
#   'Pamplona': {'min_temp': 16.01,
#    'mean_temp': 20.45,
#    'max_temp': 25.76,
#    'min_wind_speed': 0.51,
#    'mean_wind_speed': 4.03,
#    'max_wind_speed': 9.26},
#   'SantiagoDeCompostela': {'min_temp': 13.67,
#    'mean_temp': 16.18,
#    'max_temp': 19.84,
#    'min_wind_speed': 0,
#    'mean_wind_speed': 1.77,
#    'max_wind_speed': 4.02},
#   'Madrid': {'min_temp': 14.66,
#    'mean_temp': 17.89,
#    'max_temp': 21.35,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 2.65,
#    'max_wind_speed': 4.92},
#   'Merida': {'min_temp': 15.38,
#    'mean_temp': 19.53,
#    'max_temp': 24.54,
#    'min_wind_speed': 1.2,
#    'mean_wind_speed': 2.88,
#    'max_wind_speed': 4.62},
#   'Zaragoza': {'min_temp': 16.92,
#    'mean_temp': 21.16,
#    'max_temp': 26.61,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.8,
#    'max_wind_speed': 4.63},
#   'SantaCruzDeTenerife': {'min_temp': 19.63,
#    'mean_temp': 22.18,
#    'max_temp': 25.25,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.91,
#    'max_wind_speed': 4.02},
#   'Santander': {'min_temp': 16.92,
#    'mean_temp': 19.85,
#    'max_temp': 23.28,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 2.03,
#    'max_wind_speed': 4.02},
#   'Palma': {'min_temp': 22.91,
#    'mean_temp': 26.21,
#    'max_temp': 30.37,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.66,
#    'max_wind_speed': 6.26},
#   'Murcia': {'min_temp': 22.64,
#    'mean_temp': 25.64,
#    'max_temp': 30.26,
#    'min_wind_speed': 0.42,
#    'mean_wind_speed': 1.16,
#    'max_wind_speed': 4.02},
#   'Logrono': {'min_temp': 16.35,
#    'mean_temp': 19.13,
#    'max_temp': 23.77,
#    'min_wind_speed': 1.03,
#    'mean_wind_speed': 2.67,
#    'max_wind_speed': 7.72},
#   'Vitoria-gasteiz': {'min_temp': 14.73,
#    'mean_temp': 17.89,
#    'max_temp': 22.95,
#    'min_wind_speed': 0.45,
#    'mean_wind_speed': 1.99,
#    'max_wind_speed': 7.2}}}

# %%
# https://stackoverflow.com/a/66072187

from lxml import etree
import typing

def obj_to_xml(obj: typing.Union[bool, float, int, str, dict, list], parent_element: typing.Optional[etree.Element] = None, new_element_name: str = 'root') -> etree.Element:
    """
    Recursively walk an object and return its XML representation.

    Args:
        parent_element (typing.Optional[etree.Element]): The element that will be the parent of the element that this
            function will create and return.

        new_element_name (str): The name of the root element that will be created.

        obj (typing.Union[bool, float, int, str, dict, list]): The object to return XML for.

    Returns:
        result (etree.Element): An XML element.

    """

    if parent_element is not None:
        new_element = etree.SubElement(parent_element, new_element_name)

    else:
        new_element = etree.Element(new_element_name)

    if type(obj) == dict:
        for key, value in obj.items():
            if type(value) in (dict, list):
                obj_to_xml(value, new_element, key)

            else:
                # Convert values to a string, make sure boolean values are lowercase
                new_element.attrib[key] = str(value).lower() if type(value) == bool else str(value)

    elif type(obj) == list:
        for list_item in obj:
            # List items have to have a name.  Here we borrow "li" from HTML which stands for list item.
            obj_to_xml(list_item, new_element, 'li')

    else:
        # Convert everything to a string, make sure boolean values are lowercase
        new_element.text = str(obj).lower() if type(obj) == bool else str(obj)

    return new_element

# %%
root = obj_to_xml(obj, new_element_name='weather')
root.attrib['country'] = 'Spain'
root.attrib['date'] = '2021-09-25'
tree = etree.ElementTree(root)
xml_str = etree.tostring(tree, encoding='unicode', pretty_print=True)
print(xml_str)
# Out:
# <weather country="Spain" date="2021-09-25">
#   <summary mean_temp="20.43" mean_wind_speed="1.99" coldest_place="Valladolid" warmest_place="Palma" windiest_place="Pamplona"/>
#   <cities>
#     <Oviedo min_temp="14.26" mean_temp="17.0" max_temp="21.96" min_wind_speed="0.17" mean_wind_speed="1.54" max_wind_speed="6.26"/>
#     <Barcelona min_temp="21.66" mean_temp="24.21" max_temp="27.38" min_wind_speed="0.45" mean_wind_speed="1.26" max_wind_speed="3.6"/>
#     <Valencia min_temp="20.9" mean_temp="23.31" max_temp="27.57" min_wind_speed="0.45" mean_wind_speed="1.45" max_wind_speed="4.47"/>
#     <Toledo min_temp="16.11" mean_temp="19.52" max_temp="23.49" min_wind_speed="1.34" mean_wind_speed="3.86" max_wind_speed="7.04"/>
#     <Valladolid min_temp="12.56" mean_temp="15.61" max_temp="19.51" min_wind_speed="0.45" mean_wind_speed="2.22" max_wind_speed="8.23"/>
#     <Seville min_temp="17.24" mean_temp="21.6" max_temp="27.13" min_wind_speed="0.45" mean_wind_speed="1.04" max_wind_speed="2.24"/>
#     <Pamplona min_temp="16.01" mean_temp="20.45" max_temp="25.76" min_wind_speed="0.51" mean_wind_speed="4.03" max_wind_speed="9.26"/>
#     <SantiagoDeCompostela min_temp="13.67" mean_temp="16.18" max_temp="19.84" min_wind_speed="0" mean_wind_speed="1.77" max_wind_speed="4.02"/>
#     <Madrid min_temp="14.66" mean_temp="17.89" max_temp="21.35" min_wind_speed="0.45" mean_wind_speed="2.65" max_wind_speed="4.92"/>
#     <Merida min_temp="15.38" mean_temp="19.53" max_temp="24.54" min_wind_speed="1.2" mean_wind_speed="2.88" max_wind_speed="4.62"/>
#     <Zaragoza min_temp="16.92" mean_temp="21.16" max_temp="26.61" min_wind_speed="0.45" mean_wind_speed="1.8" max_wind_speed="4.63"/>
#     <SantaCruzDeTenerife min_temp="19.63" mean_temp="22.18" max_temp="25.25" min_wind_speed="0.45" mean_wind_speed="1.91" max_wind_speed="4.02"/>
#     <Santander min_temp="16.92" mean_temp="19.85" max_temp="23.28" min_wind_speed="0.45" mean_wind_speed="2.03" max_wind_speed="4.02"/>
#     <Palma min_temp="22.91" mean_temp="26.21" max_temp="30.37" min_wind_speed="0.45" mean_wind_speed="1.66" max_wind_speed="6.26"/>
#     <Murcia min_temp="22.64" mean_temp="25.64" max_temp="30.26" min_wind_speed="0.42" mean_wind_speed="1.16" max_wind_speed="4.02"/>
#     <Logrono min_temp="16.35" mean_temp="19.13" max_temp="23.77" min_wind_speed="1.03" mean_wind_speed="2.67" max_wind_speed="7.72"/>
#     <Vitoria-gasteiz min_temp="14.73" mean_temp="17.89" max_temp="22.95" min_wind_speed="0.45" mean_wind_speed="1.99" max_wind_speed="7.2"/>
#   </cities>
# </weather>

# %%
with open('out.xml', 'w') as f:
    f.write(xml_str)
